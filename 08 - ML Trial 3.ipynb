# %%
# MSM VM config prep
import findspark
findspark.init('/home/mitch/spark-3.3.0-bin-hadoop2')
import pyspark
 
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('BApredsV2').getOrCreate()

# --- suppress future spark warnings/error/etc output ---
spark.sparkContext.setLogLevel("OFF")

# %%
df2 = pd.read_pickle('OLDbioavailabilityData_w_Frags_simpler.pkl')
    
df3 = pd.read_pickle('bioavailabilityData_w_Frags__final.pkl')
    
data = pd.merge(df2,df3,how='left',left_on='drug_name',right_on='drug_name')

# %%
df1['Name'].nunique()
# Out:
# 1475

# %%
df1['smile'].nunique()
# Out:
# 1587

# %%
df1[df1['Name']=='oseltamivir']
# Out:
#      _c0         Name                                    smile  BA_pct  \
# 225  225  oseltamivir      CCC(CC)OC1C=C(C(=O)O)CC(N)C1N=C(C)O    79.0
# 356  356  oseltamivir  CCOC(=O)C1=CC(OC(CC)CC)C(N=C(C)O)C(N)C1    75.0
#
#        MolWt  ExactMolWt       qed  MolLogP    MolMR   VSA_total  ...  \
# 225  284.356  284.173607  0.507782   1.6472  77.0800  118.311993  ...
# 356  312.410  312.204907  0.426473   2.1257  86.0772  131.472948  ...
#
#      fracVSA_SlogP07  fracVSA_SlogP08  fracVSA_SlogP09  fracVSA_SlogP10  \
# 225              0.0              0.0              0.0              0.0
# 356              0.0              0.0              0.0              0.0
#
#      fracVSA_SlogP11  fracVSA_SlogP12  label1  label2  label3a  label3b
# 225              0.0              0.0    high    high     high     high
# 356              0.0              0.0    high    high     high     high
#
# [2 rows x 146 columns]

# %%
df2[df2['drug_name']=='oseltamivir']
# Out:
#        drug_name                              drug_smiles  ba_pct  \
# 225  oseltamivir      CCC(CC)OC1C=C(C(=O)O)CC(N)C1N=C(C)O    79.0
# 356  oseltamivir  CCOC(=O)C1=CC(OC(CC)CC)C(N=C(C)O)C(N)C1    75.0
#
#                                              frags_all  \
# 225  [C1C=C(C(=O)O)CCC1N=CO, *CCCC*, OC, C(=O)CCC(=...
# 356  [C1C=C(C(=O)O)CCC1N=CO, *CCCC*, OC, C(=O)CCC(=...
#
#                                           frags_better  \
# 225  [CCN, C(=O)O, CCCC(=O)O, CCO, CC#C, CCCCC(=O)O...
# 356  [CCN, C(=O)O, CCCC(=O)O, CCO, CC#C, CCCCC(=O)O...
#
#                                             frags_best  \
# 225  [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# 356  [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
#
#                   frags_efgs                         frags_brics
# 225  [C=CC(=O)O, O, N=CO, N]  [C(=O)C1=CCC(N=CO)CC1, CCC, CC, O]
# 356  [C=CC(=O)O, O, N=CO, N]  [C(=O)C1=CCC(N=CO)CC1, CCC, CC, O]

# %%
df3[df3['drug_name']=='oseltamivir']
# Out:
#        drug_name                              drug_smiles ba_pct  \
# 225  oseltamivir  CCOC(=O)C1=CC(OC(CC)CC)C(N=C(C)O)C(N)C1   79.0
#
#                                             frags3_all num_frags3_all  \
# 225  [N, *N*, CO, CCN, C(=O)O, C, *C*, CCCC(=O)O, O...             79
#
#                                             frags4_all num_frags4_all  \
# 225  [N, [*]N[*], *N*, CO, [*]CO, CCN, [*]CCN, C(C)...            241
#
#                                      fragments3_subset count_frags3_subset  \
# 225  [CCN, C(=O)O, CCCC(=O)O, CCO, CC#C, CCCCC(=O)O...                  52
#
#                                      fragments4_subset count_frags4_subset  \
# 225  [CCN, [*]CCN, C(C)O, [*]C(C)O, C(=O)O, [*]C(=O...                 201
#
#                                     fragments3_subset2  \
# 225  [C(=O)O, CCCC(=O)O, CCO, CCCCC(=O)O, C1=CCCCC1...
#
#                                     fragments4_subset2  \
# 225  [C(=O)O, [*]C(=O)O, CCCC(=O)O, [*]CCCC(=O)O, C...
#
#                   frags_efgs                         frags_brics BRICS_count
# 225  [C=CC(=O)O, O, N=CO, N]  [C(=O)C1=CCC(N=CO)CC1, CCC, O, CC]           4

# %%
data[data['drug_name']=='oseltamivir']
# Out:
#        drug_name                            drug_smiles_x  ba_pct_x  \
# 225  oseltamivir      CCC(CC)OC1C=C(C(=O)O)CC(N)C1N=C(C)O      79.0
# 356  oseltamivir  CCOC(=O)C1=CC(OC(CC)CC)C(N=C(C)O)C(N)C1      75.0
#
#                                              frags_all  \
# 225  [C1C=C(C(=O)O)CCC1N=CO, *CCCC*, OC, C(=O)CCC(=...
# 356  [C1C=C(C(=O)O)CCC1N=CO, *CCCC*, OC, C(=O)CCC(=...
#
#                                           frags_better  \
# 225  [CCN, C(=O)O, CCCC(=O)O, CCO, CC#C, CCCCC(=O)O...
# 356  [CCN, C(=O)O, CCCC(=O)O, CCO, CC#C, CCCCC(=O)O...
#
#                                             frags_best  \
# 225  [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# 356  [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
#
#                 frags_efgs_x                       frags_brics_x  \
# 225  [C=CC(=O)O, O, N=CO, N]  [C(=O)C1=CCC(N=CO)CC1, CCC, CC, O]
# 356  [C=CC(=O)O, O, N=CO, N]  [C(=O)C1=CCC(N=CO)CC1, CCC, CC, O]
#
#                                drug_smiles_y ba_pct_y  ... num_frags4_all  \
# 225  CCOC(=O)C1=CC(OC(CC)CC)C(N=C(C)O)C(N)C1     79.0  ...            241
# 356  CCOC(=O)C1=CC(OC(CC)CC)C(N=C(C)O)C(N)C1     79.0  ...            241
#
#                                      fragments3_subset count_frags3_subset  \
# 225  [CCN, C(=O)O, CCCC(=O)O, CCO, CC#C, CCCCC(=O)O...                  52
# 356  [CCN, C(=O)O, CCCC(=O)O, CCO, CC#C, CCCCC(=O)O...                  52
#
#                                      fragments4_subset count_frags4_subset  \
# 225  [CCN, [*]CCN, C(C)O, [*]C(C)O, C(=O)O, [*]C(=O...                 201
# 356  [CCN, [*]CCN, C(C)O, [*]C(C)O, C(=O)O, [*]C(=O...                 201
#
#                                     fragments3_subset2  \
# 225  [C(=O)O, CCCC(=O)O, CCO, CCCCC(=O)O, C1=CCCCC1...
# 356  [C(=O)O, CCCC(=O)O, CCO, CCCCC(=O)O, C1=CCCCC1...
#
#                                     fragments4_subset2  \
# 225  [C(=O)O, [*]C(=O)O, CCCC(=O)O, [*]CCCC(=O)O, C...
# 356  [C(=O)O, [*]C(=O)O, CCCC(=O)O, [*]CCCC(=O)O, C...
#
#                 frags_efgs_y                       frags_brics_y BRICS_count
# 225  [C=CC(=O)O, O, N=CO, N]  [C(=O)C1=CCC(N=CO)CC1, CCC, O, CC]           4
# 356  [C=CC(=O)O, O, N=CO, N]  [C(=O)C1=CCC(N=CO)CC1, CCC, O, CC]           4
#
# [2 rows x 23 columns]

# %%
len(data)
# Out:
# 1588

# %%
labels_and_calcs = spark.read.csv("bioavailability_data_final.csv",inferSchema=True,sep=',',header=True)
df1 = labels_and_calcs.toPandas()

len(df3)
# Out:
# 1475

# %%
data.query('ba_pct_x != ba_pct_y')
# Out:
#            drug_name                                      drug_smiles_x  \
# 356      oseltamivir            CCOC(=O)C1=CC(OC(CC)CC)C(N=C(C)O)C(N)C1
# 577       cefuroxime  CON=C(C(O)=NC1C(=O)N2C(C(=O)OC(C)OC(C)=O)=C(CO...
# 580    amitriptyline                     CN(C)CCC=C1c2ccccc2CCc2ccccc21
# 819   dydrogesterone    CC(=O)C1(C)CCC2C3C=C(C)C4=CC(=O)CCC4(C)C3CCC21C
# 856        megestrol  CC(=O)OC1(C(C)=O)CCC2C3CC(C)C4=CC(=O)CCC4(C)C3...
# ...              ...                                                ...
# 1555        atenolol                     CC(C)NCC(O)COc1ccc(CC(N)=O)cc1
# 1556      nordazepam                   O=C1CN=C(c2ccccc2)c2cc(Cl)ccc2N1
# 1557       sulpiride             CCN1CCCC1CNC(=O)c1cc(S(N)(=O)=O)ccc1OC
# 1559   ciprofloxacin         O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O
# 1578     abiraterone  CC(=O)OC1CCC2(C)C(=CCC3C2CCC2(C)C(c4cccnc4)=CC...
#
#       ba_pct_x                                          frags_all  \
# 356       75.0  [C1C=C(C(=O)O)CCC1N=CO, *CCCC*, OC, C(=O)CCC(=...
# 577       50.0  [OC, SC, *OCO*, CCCN, CC, *c1ccco1, O, C(CC(=O...
# 580       48.0  [*CCCC*, *c1ccccc, C(CCCCCCCCCCCC, CC, *C1CCCC...
# 819       50.0  [*CCCC*, C1CCC2C3C=CC4=CC(=O)CCC4C3CCC21C, C(=...
# 856       10.0  [*CCCC*, C(=O)C=O, OC, C1CCC2C3C=CC4=CC(=O)CCC...
# ...        ...                                                ...
# 1555      56.0  [*CCCC*, CCC(=N)O, OC, CC(=N)O, CCCN, CC, *CCC...
# 1556      80.0  [*CCCC*, C1=Nc2ccccc2C(c2ccccc2)=NC1, c1cccc(C...
# 1557      36.0  [*CS(*)(=O)=O, OC, SC, C(=O)C(=C)CC, CCCN, CC,...
# 1559      69.0  [C(=O)C(=C)CC, CCCN, CC, C(CC(=O)O, CN, CCCCC,...
# 1578      50.0  [CC12CCCCC1=CCC1C2CCC2C(c3cccnc3)=CCC12, *CCCC...
#
#                                            frags_better  \
# 356   [CCN, C(=O)O, CCCC(=O)O, CCO, CC#C, CCCCC(=O)O...
# 577   [*C1CCCO1, CCN, OC(=N)O, C(=O)O, CCCC(=O)O, CC...
# 580   [CCN, CC#C, CCC, CCCC, CC=C, *CC(*)C*, CC(CCC,...
# 819   [CCO, CC#C, CCC, CCCC, CC=C, C(=O)CC, *CC(*)C*...
# 856   [C(=O)O, CCO, CCCO, CC#C, CCC, CCCC, CC=C, C(=...
# ...                                                 ...
# 1555  [c1ccccc1, CCN, CC(=N)O, CCO, CCCO, CC#C, CCC,...
# 1556  [c1ccccc1, *c1ccccc1, CCN, CC#C, CCC, CCCC, CN...
# 1557  [*c1ccccc1, CCN, CC(=N)O, C1CCCN1C, *C1CCCN1, ...
# 1559  [CCN, C(=O)O, CCCC(=O)O, CCO, CC#C, CCCCC(=O)O...
# 1578  [c1cccnc1, *c1cccnc1, CCN, C(=O)O, CCO, CC#C, ...
#
#                                              frags_best  \
# 356   [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# 577   [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# 580   [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# 819   [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# 856   [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# ...                                                 ...
# 1555  [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# 1556  [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# 1557  [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# 1559  [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
# 1578  [CCCCN, S(=O)(=O)CCCC, NC=N, S(=O)(=O)CCC, S(=...
#
#                                            frags_efgs_x  \
# 356                             [C=CC(=O)O, O, N=CO, N]
# 577   [N=C(O)C=NO, C=C(C(=O)OCOC=O)N(C=O)CS, N=C(O)O...
# 580                        [N, C=C, c1ccccc1, c1ccccc1]
# 819                                    [C=O, C=CC=CC=O]
# 856                                 [O=CO, C=O, C=CC=O]
# ...                                                 ...
# 1555                          [N, O, O, NC=O, c1ccccc1]
# 1556                [NC=O, C=N, Cl, c1ccccc1, c1ccccc1]
# 1557                   [N, NC=O, NS(=O)=O, O, c1ccccc1]
# 1559               [O=CO, N, N, F, O=c1cc[nH]c2ccccc12]
# 1578                         [O=CO, C=C, C=C, c1ccncc1]
#
#                                           frags_brics_x  \
# 356                  [C(=O)C1=CCC(N=CO)CC1, CCC, CC, O]
# 577   [C(=O)C1=C(CCSC2C(N=CC(=NOC)c3ccco3)C(=O)N12, ...
# 580                    [C1c2ccccc2CCc2ccccc21, CCC, NC]
# 819             [C1CCC2C3C=CC4=CC(=O)CCC4C3CCC21C, C=O]
# 856   [C1CCC2C3CCC4=CC(=O)CCC4C3CCC21C, C1CCC2C3CCC4...
# ...                                                 ...
# 1555                    [c1ccccc1, CCC, CC=O, CC, O, N]
# 1556                     [O=C1CN=C(c2ccccc2)c2ccccc2N1]
# 1557    [c1ccc(S(=O)=O)cc1, N1CCCC1, C=O, OC, N, CC, C]
# 1559      [n1ccc(=O)c2ccccc21, N1CCNCC1, C1CC1, C(=O)O]
# 1578  [C1CCC2C(=CCC3C2CCC2C(c4cccnc4)=CCC32)C1, C=O, O]
#
#                                           drug_smiles_y ba_pct_y  ...  \
# 356             CCOC(=O)C1=CC(OC(CC)CC)C(N=C(C)O)C(N)C1     79.0  ...
# 577   CON=C(C(O)=NC1C(=O)N2C(C(=O)OC(C)OC(C)=O)=C(CO...     32.0  ...
# 580                      CN(C)CCC=C1c2ccccc2CCc2ccccc21     55.0  ...
# 819     CC(=O)C1(C)CCC2C3C=C(C)C4=CC(=O)CCC4(C)C3CCC21C     25.0  ...
# 856   CC(=O)OC1(C(C)=O)CCC2C3CC(C)C4=CC(=O)CCC4(C)C3...     90.0  ...
# ...                                                 ...      ...  ...
# 1555                     CC(C)NCC(O)COc1ccc(CC(N)=O)cc1     97.0  ...
# 1556                   O=C1CN=C(c2ccccc2)c2cc(Cl)ccc2N1     50.0  ...
# 1557             CCN1CCCC1CNC(=O)c1cc(S(N)(=O)=O)ccc1OC     27.0  ...
# 1559         O=C(O)c1cn(C2CC2)c2cc(N3CCNCC3)c(F)cc2c1=O     60.0  ...
# 1578  CC(=O)OC1CCC2(C)C(=CCC3C2CCC2(C)C(c4cccnc4)=CC...      0.0  ...
#
#      num_frags4_all                                  fragments3_subset  \
# 356             241  [CCN, C(=O)O, CCCC(=O)O, CCO, CC#C, CCCCC(=O)O...
# 577             295  [*C1CCCO1, CCN, OC(=N)O, [*]OC(=N)O, C(=O)O, C...
# 580             118  [CCN, CC#C, CCC, CCCC, CC=C, N(C)C, [*]N(C)C, ...
# 819             243  [CCO, CC#C, CCC, CCCC, CC=C, C(=O)CC, *C1CCCC1...
# 856             295  [C(=O)O, CCO, CCCO, CC#C, CCC, CCCC, CC=C, C(=...
# ...             ...                                                ...
# 1555            183  [c1ccccc1, CCN, CC(=N)O, CCO, CCCO, C(C)C, CC#...
# 1556            182  [c1ccccc1, *c1ccccc1, CCN, CC#C, CCC, CCCC, CN...
# 1557            302  [c1ccccc1, *c1ccccc1, CCN, CC(=N)O, C1CCCN1C, ...
# 1559            256  [CCN, C(=O)O, [*]C(=O)O, CCCC(=O)O, CCO, CC#C,...
# 1578            223  [c1cccnc1, *c1cccnc1, CCN, C(=O)O, CCO, CC#C, ...
#
#      count_frags3_subset                                  fragments4_subset  \
# 356                   52  [CCN, [*]CCN, C(C)O, [*]C(C)O, C(=O)O, [*]C(=O...
# 577                   78  [*C1CCCO1, CCN, [*]CCN, OC(=N)O, [*]OC(=N)O, C...
# 580                   33  [CCN, [*]CCN, [*]c1ccccc1[*], C(C)C, [*]C(C)C[...
# 819                   56  [C(C)O, [*]C(C)O, CC(C)O, [*]CC(C)O, CCO, C(C)...
# 856                   66  [C(C)O, [*]C(C)O, C(=O)O, [*]C(=O)O, CC(C)O, [...
# ...                  ...                                                ...
# 1555                  48  [c1ccccc1, CCN, [*]CCN, C(C)O, [*]C(C)O, CC(=N...
# 1556                  49  [c1ccccc1, [*]c1ccccc1, *c1ccccc1, CCN, [*]CCN...
# 1557                  84  [c1ccccc1, [*]c1ccccc1, *c1ccccc1, CCN, [*]CCN...
# 1559                  73  [CCN, [*]CCN, C(C)O, [*]C(C)O, C(=O)O, [*]C(=O...
# 1578                  50  [c1cccnc1, [*]c1cccnc1, *c1cccnc1, CCN, [*]CCN...
#
#      count_frags4_subset                                 fragments3_subset2  \
# 356                  201  [C(=O)O, CCCC(=O)O, CCO, CCCCC(=O)O, C1=CCCCC1...
# 577                  247  [*C1CCCO1, OC(=N)O, [*]OC(=N)O, C(=O)O, CCCC(=...
# 580                   95  [N(C)C, [*]N(C)C, CCCCC, [*]CCC[*], CCCCN, CCC...
# 819                  221  [CCO, C(=O)CC, *C1CCCC1=C, C(C)=O, [*]C(C)=O, ...
# 856                  264  [C(=O)O, CCO, CCCO, C(=O)CC, *C1CCCC1=C, C(C)=...
# ...                  ...                                                ...
# 1555                 150  [c1ccccc1, CC(=N)O, CCO, CCCO, C(C)C, C1=CCCCC...
# 1556                 149  [c1ccccc1, *c1ccccc1, CN=CC, *C1CCCCC1, CCCl, ...
# 1557                 255  [c1ccccc1, *c1ccccc1, CC(=N)O, C1CCCN1C, *C1CC...
# 1559                 225  [C(=O)O, [*]C(=O)O, CCCC(=O)O, CCO, CCCCC(=O)O...
# 1578                 181  [c1cccnc1, *c1cccnc1, C(=O)O, CCO, C(C)=O, [*]...
#
#                                      fragments4_subset2  \
# 356   [C(=O)O, [*]C(=O)O, CCCC(=O)O, [*]CCCC(=O)O, C...
# 577   [*C1CCCO1, OC(=N)O, [*]OC(=N)O, C(=O)O, [*]C(=...
# 580   [[*]c1ccccc1[*], N(C)C, [*]N(C)C, CC(C)CCC, [*...
# 819   [CC(C)O, [*]CC(C)O, CCO, [*]c1ccc([*])c([*])c1...
# 856   [C(=O)O, [*]C(=O)O, CC(C)O, [*]CC(C)O, CCO, CC...
# ...                                                 ...
# 1555  [c1ccccc1, CC(=N)O, CC(C)O, [*]CC(C)O, CCO, CC...
# 1556  [c1ccccc1, [*]c1ccccc1, *c1ccccc1, [*]c1ccccc1...
# 1557  [c1ccccc1, [*]c1ccccc1, *c1ccccc1, C(CC)C(=N)O...
# 1559  [C(=O)O, [*]C(=O)O, CCCC(=O)O, [*]CCCC(=O)O, C...
# 1578  [c1cccnc1, [*]c1cccnc1, *c1cccnc1, C(=O)O, [*]...
#
#                                            frags_efgs_y  \
# 356                             [C=CC(=O)O, O, N=CO, N]
# 577   [N=C(O)C=NO, C=C(C(=O)OCOC=O)N(C=O)CS, N=C(O)O...
# 580                        [N, C=C, c1ccccc1, c1ccccc1]
# 819                                    [C=O, C=CC=CC=O]
# 856                                 [O=CO, C=O, C=CC=O]
# ...                                                 ...
# 1555                          [N, O, O, NC=O, c1ccccc1]
# 1556                [NC=O, C=N, Cl, c1ccccc1, c1ccccc1]
# 1557                   [N, NC=O, NS(=O)=O, O, c1ccccc1]
# 1559               [O=CO, N, N, F, O=c1cc[nH]c2ccccc12]
# 1578                         [O=CO, C=C, C=C, c1ccncc1]
#
#                                           frags_brics_y BRICS_count
# 356                  [C(=O)C1=CCC(N=CO)CC1, CCC, O, CC]           4
# 577   [C(=O)C1=C(CCSC2C(N=CC(=NOC)c3ccco3)C(=O)N12, ...           5
# 580                    [C1c2ccccc2CCc2ccccc21, CCC, NC]           3
# 819             [C1CCC2C3C=CC4=CC(=O)CCC4C3CCC21C, C=O]           2
# 856   [C1CCC2C3CCC4=CC(=O)CCC4C3CCC21C, C1CCC2C3CCC4...           5
# ...                                                 ...         ...
# 1555                    [c1ccccc1, CCC, CC=O, CC, N, O]           6
# 1556                     [O=C1CN=C(c2ccccc2)c2ccccc2N1]           1
# 1557    [c1ccc(S(=O)=O)cc1, N1CCCC1, C=O, N, CC, C, OC]           7
# 1559      [n1ccc(=O)c2ccccc21, N1CCNCC1, C(=O)O, C1CC1]           4
# 1578  [C1CCC2C(=CCC3C2CCC2C(c4cccnc4)=CCC32)C1, C=O, O]           3
#
# [96 rows x 23 columns]

# %%
df3.infer_objects().dtypes
# Out:
# drug_name               object
# drug_smiles             object
# ba_pct                 float64
# frags3_all              object
# num_frags3_all           int64
# frags4_all              object
# num_frags4_all           int64
# fragments3_subset       object
# count_frags3_subset      int64
# fragments4_subset       object
# count_frags4_subset      int64
# fragments3_subset2      object
# fragments4_subset2      object
# frags_efgs              object
# frags_brics             object
# BRICS_count              int64
# dtype: object

# %%
import pandas as pd

df2 = pd.read_pickle('OLDbioavailabilityData_w_Frags_simpler.pkl')
df2 = df2.drop(columns=['drug_smiles','ba_pct'])
    
    
df2spark = spark.createDataFrame(df2)
    
df2spark.printSchema()
# Out:
# root
#  |-- drug_name: string (nullable = true)
#  |-- frags_all: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_better: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_best: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_efgs: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_brics: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
import pandas as pd

df3 = pd.read_pickle('bioavailabilityData_w_Frags__final.pkl')
df3 = df3.drop(columns=['drug_smiles','ba_pct'])
    
    
df3spark = spark.createDataFrame(df3)
    
df3spark.printSchema()
# Out:
# root
#  |-- drug_name: string (nullable = true)
#  |-- frags3_all: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- num_frags3_all: long (nullable = true)
#  |-- frags4_all: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- num_frags4_all: long (nullable = true)
#  |-- fragments3_subset: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- count_frags3_subset: long (nullable = true)
#  |-- fragments4_subset: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- count_frags4_subset: long (nullable = true)
#  |-- fragments3_subset2: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fragments4_subset2: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_efgs: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_brics: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- BRICS_count: long (nullable = true)

# %%
import pandas as pd
def load_data_and_merge():
    labels_and_calcs = spark.read.csv("bioavailability_data_final.csv",inferSchema=True,sep=',',header=True)
    df1 = labels_and_calcs.toPandas()

    df2 = pd.read_pickle('OLDbioavailabilityData_w_Frags_simpler.pkl')
    df2 = df2.drop(columns=['drug_smiles','ba_pct'])
    
    data_temp = pd.merge(df1,df2,how='left',left_on='_c0',right_on=df2.index)
    
    data_temp = data_temp.infer_objects()
    
    df3 = pd.read_pickle('bioavailabilityData_w_Frags__final.pkl')
    #df3 = df3.drop(columns=['ba_pct'])
    df3 = df3.infer_objects()
    
    data_temp = pd.merge(data_temp,df3,how='left',left_on='smile',right_on='drug_smiles')
    
    return data_temp
    #data = spark.createDataFrame(data_temp)
    #return data

data = load_data_and_merge()

# %%
data.dtypes
# Out:
# _c0                     int32
# Name                   object
# smile                  object
# BA_pct                float64
# MolWt                 float64
#                        ...
# fragments3_subset2     object
# fragments4_subset2     object
# frags_efgs_y           object
# frags_brics_y          object
# BRICS_count           float64
# Length: 168, dtype: object

# %%
from pyspark.sql.types import *

# Auxiliar functions
def equivalent_type(f):
    if f == 'datetime64[ns]': return TimestampType()
    elif f == 'int64': return LongType()
    elif f == 'int32': return IntegerType()
    elif f == 'float64': return DoubleType()
    elif f == 'float32': return FloatType()
    else: return StringType()

def define_structure(string, format_type):
    try: typo = equivalent_type(format_type)
    except: typo = StringType()
    return StructField(string, typo)

# Given pandas dataframe, it will return a spark's dataframe.
def pandas_to_spark(pandas_df):
    columns = list(pandas_df.columns)
    types = list(pandas_df.dtypes)
    struct_list = []
    for column, typo in zip(columns, types):
        if column[0:4] == 'frag':
            struct_list.append(StructField(column,ArrayType(StringType(),True)))
        else:
            struct_list.append(define_structure(column, typo))
    p_schema = StructType(struct_list)
    return spark.createDataFrame(pandas_df, p_schema)

# %%
#test = spark.createDataFrame(data)
test = pandas_to_spark(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 2>()
#       1 #test = spark.createDataFrame(data)
# ----> 2 test = pandas_to_spark(data)
#
# Input In [64], in pandas_to_spark(pandas_df)
#      26         struct_list.append(define_structure(column, typo))
#      27 p_schema = StructType(struct_list)
# ---> 28 return spark.createDataFrame(pandas_df, p_schema)
#
# File ~/spark-3.3.0-bin-hadoop2/python/pyspark/sql/session.py:891, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     888     has_pandas = False
#     889 if has_pandas and isinstance(data, pandas.DataFrame):
#     890     # Create a DataFrame from pandas DataFrame.
# --> 891     return super(SparkSession, self).createDataFrame(  # type: ignore[call-overload]
#     892         data, schema, samplingRatio, verifySchema
#     893     )
#     894 return self._create_dataframe(
#     895     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#     896 )
#
# File ~/spark-3.3.0-bin-hadoop2/python/pyspark/sql/pandas/conversion.py:437, in SparkConversionMixin.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     435             raise
#     436 converted_data = self._convert_from_pandas(data, schema, timezone)
# --> 437 return self._create_dataframe(converted_data, schema, samplingRatio, verifySchema)
#
# File ~/spark-3.3.0-bin-hadoop2/python/pyspark/sql/session.py:936, in SparkSession._create_dataframe(self, data, schema, samplingRatio, verifySchema)
#     934     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#     935 else:
# --> 936     rdd, struct = self._createFromLocal(map(prepare, data), schema)
#     937 assert self._jvm is not None
#     938 jrdd = self._jvm.SerDeUtil.toJavaArray(rdd._to_java_object_rdd())
#
# File ~/spark-3.3.0-bin-hadoop2/python/pyspark/sql/session.py:628, in SparkSession._createFromLocal(self, data, schema)
#     626 # make sure data could consumed multiple times
#     627 if not isinstance(data, list):
# --> 628     data = list(data)
#     630 if schema is None or isinstance(schema, (list, tuple)):
#     631     struct = self._inferSchemaFromList(data, names=schema)
#
# File ~/spark-3.3.0-bin-hadoop2/python/pyspark/sql/session.py:910, in SparkSession._create_dataframe.<locals>.prepare(obj)
#     908 @no_type_check
#     909 def prepare(obj):
# --> 910     verify_func(obj)
#     911     return obj
#
# File ~/spark-3.3.0-bin-hadoop2/python/pyspark/sql/types.py:1722, in _make_type_verifier.<locals>.verify(obj)
#    1720 def verify(obj: Any) -> None:
#    1721     if not verify_nullability(obj):
# -> 1722         verify_value(obj)
#
# File ~/spark-3.3.0-bin-hadoop2/python/pyspark/sql/types.py:1700, in _make_type_verifier.<locals>.verify_struct(obj)
#    1693         raise ValueError(
#    1694             new_msg(
#    1695                 "Length of object (%d) does not match with "
#    1696                 "length of fields (%d)" % (len(obj), len(verifiers))
#    1697             )
#    1698         )
#    1699     for v, (_, verifier) in zip(obj, verifiers):
# -> 1700         verifier(v)
#    1701 elif hasattr(obj, "__dict__"):
#    1702     d = obj.__dict__
#
# File ~/spark-3.3.0-bin-hadoop2/python/pyspark/sql/types.py:1722, in _make_type_verifier.<locals>.verify(obj)
#    1720 def verify(obj: Any) -> None:
#    1721     if not verify_nullability(obj):
# -> 1722         verify_value(obj)
#
# File ~/spark-3.3.0-bin-hadoop2/python/pyspark/sql/types.py:1658, in _make_type_verifier.<locals>.verify_array(obj)
#    1656 def verify_array(obj: Any) -> None:
#    1657     assert_acceptable_types(obj)
# -> 1658     verify_acceptable_types(obj)
#    1659     for i in obj:
#    1660         element_verifier(i)
#
# File ~/spark-3.3.0-bin-hadoop2/python/pyspark/sql/types.py:1592, in _make_type_verifier.<locals>.verify_acceptable_types(obj)
#    1589 def verify_acceptable_types(obj: Any) -> None:
#    1590     # subclass of them can not be fromInternal in JVM
#    1591     if type(obj) not in _acceptable_types[_type]:
# -> 1592         raise TypeError(
#    1593             new_msg("%s can not accept object %r in type %s" % (dataType, obj, type(obj)))
#    1594         )
#
# TypeError: field frags3_all: ArrayType(StringType(), True) can not accept object nan in type <class 'float'>

# %%
test.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- smile: string (nullable = true)
#  |-- BA_pct: double (nullable = true)
#  |-- MolWt: double (nullable = true)
#  |-- ExactMolWt: double (nullable = true)
#  |-- qed: double (nullable = true)
#  |-- MolLogP: double (nullable = true)
#  |-- MolMR: double (nullable = true)
#  |-- VSA_total: double (nullable = true)
#  |-- LabuteASA: double (nullable = true)
#  |-- TPSA: double (nullable = true)
#  |-- MaxPartialCharge: double (nullable = true)
#  |-- MinPartialCharge: double (nullable = true)
#  |-- MaxAbsPartialCharge: double (nullable = true)
#  |-- MinAbsPartialCharge: double (nullable = true)
#  |-- NumHAcceptors: double (nullable = true)
#  |-- NumHDonors: double (nullable = true)
#  |-- HeavyAtomCount: double (nullable = true)
#  |-- NumHeteroatoms: double (nullable = true)
#  |-- NumRotatableBonds: double (nullable = true)
#  |-- NHOHCount: double (nullable = true)
#  |-- NOCount: double (nullable = true)
#  |-- FractionCSP3: double (nullable = true)
#  |-- RingCount: double (nullable = true)
#  |-- NumAliphaticRings: double (nullable = true)
#  |-- NumAromaticRings: double (nullable = true)
#  |-- NumAliphaticHeterocycles: double (nullable = true)
#  |-- NumAromaticHeterocycles: double (nullable = true)
#  |-- NumSaturatedHeterocycles: double (nullable = true)
#  |-- NumSaturatedRings: double (nullable = true)
#  |-- BalabanJ: double (nullable = true)
#  |-- BertzCT: double (nullable = true)
#  |-- HallKierAlpha: double (nullable = true)
#  |-- PEOE_VSA1: double (nullable = true)
#  |-- PEOE_VSA2: double (nullable = true)
#  |-- PEOE_VSA3: double (nullable = true)
#  |-- PEOE_VSA4: double (nullable = true)
#  |-- PEOE_VSA5: double (nullable = true)
#  |-- PEOE_VSA6: double (nullable = true)
#  |-- PEOE_VSA7: double (nullable = true)
#  |-- PEOE_VSA8: double (nullable = true)
#  |-- PEOE_VSA9: double (nullable = true)
#  |-- PEOE_VSA10: double (nullable = true)
#  |-- PEOE_VSA11: double (nullable = true)
#  |-- PEOE_VSA12: double (nullable = true)
#  |-- PEOE_VSA13: double (nullable = true)
#  |-- PEOE_VSA14: double (nullable = true)
#  |-- SMR_VSA1: double (nullable = true)
#  |-- SMR_VSA2: double (nullable = true)
#  |-- SMR_VSA3: double (nullable = true)
#  |-- SMR_VSA4: double (nullable = true)
#  |-- SMR_VSA5: double (nullable = true)
#  |-- SMR_VSA6: double (nullable = true)
#  |-- SMR_VSA7: double (nullable = true)
#  |-- SMR_VSA8: double (nullable = true)
#  |-- SMR_VSA9: double (nullable = true)
#  |-- SMR_VSA10: double (nullable = true)
#  |-- SlogP_VSA1: double (nullable = true)
#  |-- SlogP_VSA2: double (nullable = true)
#  |-- SlogP_VSA3: double (nullable = true)
#  |-- SlogP_VSA4: double (nullable = true)
#  |-- SlogP_VSA5: double (nullable = true)
#  |-- SlogP_VSA6: double (nullable = true)
#  |-- SlogP_VSA7: double (nullable = true)
#  |-- SlogP_VSA8: double (nullable = true)
#  |-- SlogP_VSA9: double (nullable = true)
#  |-- SlogP_VSA10: double (nullable = true)
#  |-- SlogP_VSA11: double (nullable = true)
#  |-- SlogP_VSA12: double (nullable = true)
#  |-- PEOE_VSA1.1: double (nullable = true)
#  |-- PEOE_VSA2.1: double (nullable = true)
#  |-- PEOE_VSA3.1: double (nullable = true)
#  |-- PEOE_VSA4.1: double (nullable = true)
#  |-- PEOE_VSA5.1: double (nullable = true)
#  |-- PEOE_VSA6.1: double (nullable = true)
#  |-- PEOE_VSA7.1: double (nullable = true)
#  |-- PEOE_VSA8.1: double (nullable = true)
#  |-- PEOE_VSA9.1: double (nullable = true)
#  |-- PEOE_VSA10.1: double (nullable = true)
#  |-- PEOE_VSA11.1: double (nullable = true)
#  |-- PEOE_VSA12.1: double (nullable = true)
#  |-- PEOE_VSA13.1: double (nullable = true)
#  |-- PEOE_VSA14.1: double (nullable = true)
#  |-- SMR_VSA1.1: double (nullable = true)
#  |-- SMR_VSA2.1: double (nullable = true)
#  |-- SMR_VSA3.1: double (nullable = true)
#  |-- SMR_VSA4.1: double (nullable = true)
#  |-- SMR_VSA5.1: double (nullable = true)
#  |-- SMR_VSA6.1: double (nullable = true)
#  |-- SMR_VSA7.1: double (nullable = true)
#  |-- SMR_VSA8.1: double (nullable = true)
#  |-- SMR_VSA9.1: double (nullable = true)
#  |-- SMR_VSA10.1: double (nullable = true)
#  |-- SlogP_VSA1.1: double (nullable = true)
#  |-- SlogP_VSA2.1: double (nullable = true)
#  |-- SlogP_VSA3.1: double (nullable = true)
#  |-- SlogP_VSA4.1: double (nullable = true)
#  |-- SlogP_VSA5.1: double (nullable = true)
#  |-- SlogP_VSA6.1: double (nullable = true)
#  |-- SlogP_VSA7.1: double (nullable = true)
#  |-- SlogP_VSA8.1: double (nullable = true)
#  |-- SlogP_VSA9.1: double (nullable = true)
#  |-- SlogP_VSA10.1: double (nullable = true)
#  |-- SlogP_VSA11.1: double (nullable = true)
#  |-- SlogP_VSA12.1: double (nullable = true)
#  |-- fracVSA_PEOE01: double (nullable = true)
#  |-- fracVSA_PEOE02: double (nullable = true)
#  |-- fracVSA_PEOE03: double (nullable = true)
#  |-- fracVSA_PEOE04: double (nullable = true)
#  |-- fracVSA_PEOE05: double (nullable = true)
#  |-- fracVSA_PEOE06: double (nullable = true)
#  |-- fracVSA_PEOE07: double (nullable = true)
#  |-- fracVSA_PEOE08: double (nullable = true)
#  |-- fracVSA_PEOE09: double (nullable = true)
#  |-- fracVSA_PEOE10: double (nullable = true)
#  |-- fracVSA_PEOE11: double (nullable = true)
#  |-- fracVSA_PEOE12: double (nullable = true)
#  |-- fracVSA_PEOE13: double (nullable = true)
#  |-- fracVSA_PEOE14: double (nullable = true)
#  |-- fracVSA_SMR01: double (nullable = true)
#  |-- fracVSA_SMR02: double (nullable = true)
#  |-- fracVSA_SMR03: double (nullable = true)
#  |-- fracVSA_SMR04: double (nullable = true)
#  |-- fracVSA_SMR05: double (nullable = true)
#  |-- fracVSA_SMR06: double (nullable = true)
#  |-- fracVSA_SMR07: double (nullable = true)
#  |-- fracVSA_SMR08: double (nullable = true)
#  |-- fracVSA_SMR09: double (nullable = true)
#  |-- fracVSA_SMR10: double (nullable = true)
#  |-- fracVSA_SlogP01: double (nullable = true)
#  |-- fracVSA_SlogP02: double (nullable = true)
#  |-- fracVSA_SlogP03: double (nullable = true)
#  |-- fracVSA_SlogP04: double (nullable = true)
#  |-- fracVSA_SlogP05: double (nullable = true)
#  |-- fracVSA_SlogP06: double (nullable = true)
#  |-- fracVSA_SlogP07: double (nullable = true)
#  |-- fracVSA_SlogP08: double (nullable = true)
#  |-- fracVSA_SlogP09: double (nullable = true)
#  |-- fracVSA_SlogP10: double (nullable = true)
#  |-- fracVSA_SlogP11: double (nullable = true)
#  |-- fracVSA_SlogP12: double (nullable = true)
#  |-- label1: string (nullable = true)
#  |-- label2: string (nullable = true)
#  |-- label3a: string (nullable = true)
#  |-- label3b: string (nullable = true)
#  |-- drug_name_x: string (nullable = true)
#  |-- frags_all: string (nullable = true)
#  |-- frags_better: string (nullable = true)
#  |-- frags_best: string (nullable = true)
#  |-- frags_efgs_x: string (nullable = true)
#  |-- frags_brics_x: string (nullable = true)
#  |-- drug_name_y: string (nullable = true)
#  |-- drug_smiles: string (nullable = true)
#  |-- ba_pct: double (nullable = true)
#  |-- frags3_all: string (nullable = true)
#  |-- num_frags3_all: double (nullable = true)
#  |-- frags4_all: string (nullable = true)
#  |-- num_frags4_all: double (nullable = true)
#  |-- fragments3_subset: string (nullable = true)
#  |-- count_frags3_subset: double (nullable = true)
#  |-- fragments4_subset: string (nullable = true)
#  |-- count_frags4_subset: double (nullable = true)
#  |-- fragments3_subset2: string (nullable = true)
#  |-- fragments4_subset2: string (nullable = true)
#  |-- frags_efgs_y: string (nullable = true)
#  |-- frags_brics_y: string (nullable = true)
#  |-- BRICS_count: double (nullable = true)

# %%
data.printSchema()
# Out:
# root
#  |-- _c0: long (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- smile: string (nullable = true)
#  |-- BA_pct: double (nullable = true)
#  |-- MolWt: double (nullable = true)
#  |-- ExactMolWt: double (nullable = true)
#  |-- qed: double (nullable = true)
#  |-- MolLogP: double (nullable = true)
#  |-- MolMR: double (nullable = true)
#  |-- VSA_total: double (nullable = true)
#  |-- LabuteASA: double (nullable = true)
#  |-- TPSA: double (nullable = true)
#  |-- MaxPartialCharge: double (nullable = true)
#  |-- MinPartialCharge: double (nullable = true)
#  |-- MaxAbsPartialCharge: double (nullable = true)
#  |-- MinAbsPartialCharge: double (nullable = true)
#  |-- NumHAcceptors: double (nullable = true)
#  |-- NumHDonors: double (nullable = true)
#  |-- HeavyAtomCount: double (nullable = true)
#  |-- NumHeteroatoms: double (nullable = true)
#  |-- NumRotatableBonds: double (nullable = true)
#  |-- NHOHCount: double (nullable = true)
#  |-- NOCount: double (nullable = true)
#  |-- FractionCSP3: double (nullable = true)
#  |-- RingCount: double (nullable = true)
#  |-- NumAliphaticRings: double (nullable = true)
#  |-- NumAromaticRings: double (nullable = true)
#  |-- NumAliphaticHeterocycles: double (nullable = true)
#  |-- NumAromaticHeterocycles: double (nullable = true)
#  |-- NumSaturatedHeterocycles: double (nullable = true)
#  |-- NumSaturatedRings: double (nullable = true)
#  |-- BalabanJ: double (nullable = true)
#  |-- BertzCT: double (nullable = true)
#  |-- HallKierAlpha: double (nullable = true)
#  |-- PEOE_VSA1: double (nullable = true)
#  |-- PEOE_VSA2: double (nullable = true)
#  |-- PEOE_VSA3: double (nullable = true)
#  |-- PEOE_VSA4: double (nullable = true)
#  |-- PEOE_VSA5: double (nullable = true)
#  |-- PEOE_VSA6: double (nullable = true)
#  |-- PEOE_VSA7: double (nullable = true)
#  |-- PEOE_VSA8: double (nullable = true)
#  |-- PEOE_VSA9: double (nullable = true)
#  |-- PEOE_VSA10: double (nullable = true)
#  |-- PEOE_VSA11: double (nullable = true)
#  |-- PEOE_VSA12: double (nullable = true)
#  |-- PEOE_VSA13: double (nullable = true)
#  |-- PEOE_VSA14: double (nullable = true)
#  |-- SMR_VSA1: double (nullable = true)
#  |-- SMR_VSA2: double (nullable = true)
#  |-- SMR_VSA3: double (nullable = true)
#  |-- SMR_VSA4: double (nullable = true)
#  |-- SMR_VSA5: double (nullable = true)
#  |-- SMR_VSA6: double (nullable = true)
#  |-- SMR_VSA7: double (nullable = true)
#  |-- SMR_VSA8: double (nullable = true)
#  |-- SMR_VSA9: double (nullable = true)
#  |-- SMR_VSA10: double (nullable = true)
#  |-- SlogP_VSA1: double (nullable = true)
#  |-- SlogP_VSA2: double (nullable = true)
#  |-- SlogP_VSA3: double (nullable = true)
#  |-- SlogP_VSA4: double (nullable = true)
#  |-- SlogP_VSA5: double (nullable = true)
#  |-- SlogP_VSA6: double (nullable = true)
#  |-- SlogP_VSA7: double (nullable = true)
#  |-- SlogP_VSA8: double (nullable = true)
#  |-- SlogP_VSA9: double (nullable = true)
#  |-- SlogP_VSA10: double (nullable = true)
#  |-- SlogP_VSA11: double (nullable = true)
#  |-- SlogP_VSA12: double (nullable = true)
#  |-- PEOE_VSA1.1: double (nullable = true)
#  |-- PEOE_VSA2.1: double (nullable = true)
#  |-- PEOE_VSA3.1: double (nullable = true)
#  |-- PEOE_VSA4.1: double (nullable = true)
#  |-- PEOE_VSA5.1: double (nullable = true)
#  |-- PEOE_VSA6.1: double (nullable = true)
#  |-- PEOE_VSA7.1: double (nullable = true)
#  |-- PEOE_VSA8.1: double (nullable = true)
#  |-- PEOE_VSA9.1: double (nullable = true)
#  |-- PEOE_VSA10.1: double (nullable = true)
#  |-- PEOE_VSA11.1: double (nullable = true)
#  |-- PEOE_VSA12.1: double (nullable = true)
#  |-- PEOE_VSA13.1: double (nullable = true)
#  |-- PEOE_VSA14.1: double (nullable = true)
#  |-- SMR_VSA1.1: double (nullable = true)
#  |-- SMR_VSA2.1: double (nullable = true)
#  |-- SMR_VSA3.1: double (nullable = true)
#  |-- SMR_VSA4.1: double (nullable = true)
#  |-- SMR_VSA5.1: double (nullable = true)
#  |-- SMR_VSA6.1: double (nullable = true)
#  |-- SMR_VSA7.1: double (nullable = true)
#  |-- SMR_VSA8.1: double (nullable = true)
#  |-- SMR_VSA9.1: double (nullable = true)
#  |-- SMR_VSA10.1: double (nullable = true)
#  |-- SlogP_VSA1.1: double (nullable = true)
#  |-- SlogP_VSA2.1: double (nullable = true)
#  |-- SlogP_VSA3.1: double (nullable = true)
#  |-- SlogP_VSA4.1: double (nullable = true)
#  |-- SlogP_VSA5.1: double (nullable = true)
#  |-- SlogP_VSA6.1: double (nullable = true)
#  |-- SlogP_VSA7.1: double (nullable = true)
#  |-- SlogP_VSA8.1: double (nullable = true)
#  |-- SlogP_VSA9.1: double (nullable = true)
#  |-- SlogP_VSA10.1: double (nullable = true)
#  |-- SlogP_VSA11.1: double (nullable = true)
#  |-- SlogP_VSA12.1: double (nullable = true)
#  |-- fracVSA_PEOE01: double (nullable = true)
#  |-- fracVSA_PEOE02: double (nullable = true)
#  |-- fracVSA_PEOE03: double (nullable = true)
#  |-- fracVSA_PEOE04: double (nullable = true)
#  |-- fracVSA_PEOE05: double (nullable = true)
#  |-- fracVSA_PEOE06: double (nullable = true)
#  |-- fracVSA_PEOE07: double (nullable = true)
#  |-- fracVSA_PEOE08: double (nullable = true)
#  |-- fracVSA_PEOE09: double (nullable = true)
#  |-- fracVSA_PEOE10: double (nullable = true)
#  |-- fracVSA_PEOE11: double (nullable = true)
#  |-- fracVSA_PEOE12: double (nullable = true)
#  |-- fracVSA_PEOE13: double (nullable = true)
#  |-- fracVSA_PEOE14: double (nullable = true)
#  |-- fracVSA_SMR01: double (nullable = true)
#  |-- fracVSA_SMR02: double (nullable = true)
#  |-- fracVSA_SMR03: double (nullable = true)
#  |-- fracVSA_SMR04: double (nullable = true)
#  |-- fracVSA_SMR05: double (nullable = true)
#  |-- fracVSA_SMR06: double (nullable = true)
#  |-- fracVSA_SMR07: double (nullable = true)
#  |-- fracVSA_SMR08: double (nullable = true)
#  |-- fracVSA_SMR09: double (nullable = true)
#  |-- fracVSA_SMR10: double (nullable = true)
#  |-- fracVSA_SlogP01: double (nullable = true)
#  |-- fracVSA_SlogP02: double (nullable = true)
#  |-- fracVSA_SlogP03: double (nullable = true)
#  |-- fracVSA_SlogP04: double (nullable = true)
#  |-- fracVSA_SlogP05: double (nullable = true)
#  |-- fracVSA_SlogP06: double (nullable = true)
#  |-- fracVSA_SlogP07: double (nullable = true)
#  |-- fracVSA_SlogP08: double (nullable = true)
#  |-- fracVSA_SlogP09: double (nullable = true)
#  |-- fracVSA_SlogP10: double (nullable = true)
#  |-- fracVSA_SlogP11: double (nullable = true)
#  |-- fracVSA_SlogP12: double (nullable = true)
#  |-- label1: string (nullable = true)
#  |-- label2: string (nullable = true)
#  |-- label3a: string (nullable = true)
#  |-- label3b: string (nullable = true)
#  |-- drug_name: string (nullable = true)
#  |-- frags_all: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_better: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_best: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_efgs: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_brics: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
import pandas as pd
def load_data_and_merge():
    labels_and_calcs = spark.read.csv("bioavailability_data_final.csv",inferSchema=True,sep=',',header=True)
    df1 = labels_and_calcs.toPandas()

    df2 = pd.read_pickle('OLDbioavailabilityData_w_Frags_simpler.pkl')
    df2 = df2.drop(columns=['ba_pct'])
    
    df3 = pd.read_pickle('bioavailabilityData_w_Frags__final.pkl')
    df3 = df3.drop(columns=['ba_pct','frags_efgs','frags_brics'])
    
    
    temp1 = pd.merge(df1,df2,how='left',left_on='_c0',right_on=df2.index)
    
    #data = pd.merge(df3,data_temp,how='left',left_on='drug_smiles',right_on='smile')
    
    temp1 = spark.createDataFrame(temp1)
    
    temp2 = spark.createDataFrame(df3)
    
    data = temp2.join(temp1,(temp2.drug_smiles==temp1.smile),"left")
    
    return data
    #data = spark.createDataFrame(data_temp)
    #return data

data = load_data_and_merge()

# %%
df3 = pd.read_pickle('bioavailabilityData_w_Frags__final.pkl')
df3 = df3.drop(columns=['ba_pct'])
df3.columns
# Out:
# Index(['drug_name', 'drug_smiles', 'frags3_all', 'num_frags3_all',
#        'frags4_all', 'num_frags4_all', 'fragments3_subset',
#        'count_frags3_subset', 'fragments4_subset', 'count_frags4_subset',
#        'fragments3_subset2', 'fragments4_subset2', 'frags_efgs', 'frags_brics',
#        'BRICS_count'],
#       dtype='object')

# %%
test1 = spark.createDataFrame(data_temp)

# %%
test2 = spark.createDataFrame(df3)

# %%
test.printSchema()
# Out:
# root
#  |-- drug_name: string (nullable = true)
#  |-- frags3_all: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- num_frags3_all: long (nullable = true)
#  |-- frags4_all: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- num_frags4_all: long (nullable = true)
#  |-- fragments3_subset: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- count_frags3_subset: long (nullable = true)
#  |-- fragments4_subset: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- count_frags4_subset: long (nullable = true)
#  |-- fragments3_subset2: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fragments4_subset2: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_efgs: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_brics: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- BRICS_count: long (nullable = true)

# %%
data_final = test2.join(test1,(test2.drug_smiles==test1.smile),"left")

# %%
data_final.printSchema()
# Out:
# root
#  |-- drug_name: string (nullable = true)
#  |-- drug_smiles: string (nullable = true)
#  |-- frags3_all: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- num_frags3_all: long (nullable = true)
#  |-- frags4_all: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- num_frags4_all: long (nullable = true)
#  |-- fragments3_subset: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- count_frags3_subset: long (nullable = true)
#  |-- fragments4_subset: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- count_frags4_subset: long (nullable = true)
#  |-- fragments3_subset2: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fragments4_subset2: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_efgs: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_brics: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- BRICS_count: long (nullable = true)
#  |-- _c0: long (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- smile: string (nullable = true)
#  |-- BA_pct: double (nullable = true)
#  |-- MolWt: double (nullable = true)
#  |-- ExactMolWt: double (nullable = true)
#  |-- qed: double (nullable = true)
#  |-- MolLogP: double (nullable = true)
#  |-- MolMR: double (nullable = true)
#  |-- VSA_total: double (nullable = true)
#  |-- LabuteASA: double (nullable = true)
#  |-- TPSA: double (nullable = true)
#  |-- MaxPartialCharge: double (nullable = true)
#  |-- MinPartialCharge: double (nullable = true)
#  |-- MaxAbsPartialCharge: double (nullable = true)
#  |-- MinAbsPartialCharge: double (nullable = true)
#  |-- NumHAcceptors: double (nullable = true)
#  |-- NumHDonors: double (nullable = true)
#  |-- HeavyAtomCount: double (nullable = true)
#  |-- NumHeteroatoms: double (nullable = true)
#  |-- NumRotatableBonds: double (nullable = true)
#  |-- NHOHCount: double (nullable = true)
#  |-- NOCount: double (nullable = true)
#  |-- FractionCSP3: double (nullable = true)
#  |-- RingCount: double (nullable = true)
#  |-- NumAliphaticRings: double (nullable = true)
#  |-- NumAromaticRings: double (nullable = true)
#  |-- NumAliphaticHeterocycles: double (nullable = true)
#  |-- NumAromaticHeterocycles: double (nullable = true)
#  |-- NumSaturatedHeterocycles: double (nullable = true)
#  |-- NumSaturatedRings: double (nullable = true)
#  |-- BalabanJ: double (nullable = true)
#  |-- BertzCT: double (nullable = true)
#  |-- HallKierAlpha: double (nullable = true)
#  |-- PEOE_VSA1: double (nullable = true)
#  |-- PEOE_VSA2: double (nullable = true)
#  |-- PEOE_VSA3: double (nullable = true)
#  |-- PEOE_VSA4: double (nullable = true)
#  |-- PEOE_VSA5: double (nullable = true)
#  |-- PEOE_VSA6: double (nullable = true)
#  |-- PEOE_VSA7: double (nullable = true)
#  |-- PEOE_VSA8: double (nullable = true)
#  |-- PEOE_VSA9: double (nullable = true)
#  |-- PEOE_VSA10: double (nullable = true)
#  |-- PEOE_VSA11: double (nullable = true)
#  |-- PEOE_VSA12: double (nullable = true)
#  |-- PEOE_VSA13: double (nullable = true)
#  |-- PEOE_VSA14: double (nullable = true)
#  |-- SMR_VSA1: double (nullable = true)
#  |-- SMR_VSA2: double (nullable = true)
#  |-- SMR_VSA3: double (nullable = true)
#  |-- SMR_VSA4: double (nullable = true)
#  |-- SMR_VSA5: double (nullable = true)
#  |-- SMR_VSA6: double (nullable = true)
#  |-- SMR_VSA7: double (nullable = true)
#  |-- SMR_VSA8: double (nullable = true)
#  |-- SMR_VSA9: double (nullable = true)
#  |-- SMR_VSA10: double (nullable = true)
#  |-- SlogP_VSA1: double (nullable = true)
#  |-- SlogP_VSA2: double (nullable = true)
#  |-- SlogP_VSA3: double (nullable = true)
#  |-- SlogP_VSA4: double (nullable = true)
#  |-- SlogP_VSA5: double (nullable = true)
#  |-- SlogP_VSA6: double (nullable = true)
#  |-- SlogP_VSA7: double (nullable = true)
#  |-- SlogP_VSA8: double (nullable = true)
#  |-- SlogP_VSA9: double (nullable = true)
#  |-- SlogP_VSA10: double (nullable = true)
#  |-- SlogP_VSA11: double (nullable = true)
#  |-- SlogP_VSA12: double (nullable = true)
#  |-- PEOE_VSA1.1: double (nullable = true)
#  |-- PEOE_VSA2.1: double (nullable = true)
#  |-- PEOE_VSA3.1: double (nullable = true)
#  |-- PEOE_VSA4.1: double (nullable = true)
#  |-- PEOE_VSA5.1: double (nullable = true)
#  |-- PEOE_VSA6.1: double (nullable = true)
#  |-- PEOE_VSA7.1: double (nullable = true)
#  |-- PEOE_VSA8.1: double (nullable = true)
#  |-- PEOE_VSA9.1: double (nullable = true)
#  |-- PEOE_VSA10.1: double (nullable = true)
#  |-- PEOE_VSA11.1: double (nullable = true)
#  |-- PEOE_VSA12.1: double (nullable = true)
#  |-- PEOE_VSA13.1: double (nullable = true)
#  |-- PEOE_VSA14.1: double (nullable = true)
#  |-- SMR_VSA1.1: double (nullable = true)
#  |-- SMR_VSA2.1: double (nullable = true)
#  |-- SMR_VSA3.1: double (nullable = true)
#  |-- SMR_VSA4.1: double (nullable = true)
#  |-- SMR_VSA5.1: double (nullable = true)
#  |-- SMR_VSA6.1: double (nullable = true)
#  |-- SMR_VSA7.1: double (nullable = true)
#  |-- SMR_VSA8.1: double (nullable = true)
#  |-- SMR_VSA9.1: double (nullable = true)
#  |-- SMR_VSA10.1: double (nullable = true)
#  |-- SlogP_VSA1.1: double (nullable = true)
#  |-- SlogP_VSA2.1: double (nullable = true)
#  |-- SlogP_VSA3.1: double (nullable = true)
#  |-- SlogP_VSA4.1: double (nullable = true)
#  |-- SlogP_VSA5.1: double (nullable = true)
#  |-- SlogP_VSA6.1: double (nullable = true)
#  |-- SlogP_VSA7.1: double (nullable = true)
#  |-- SlogP_VSA8.1: double (nullable = true)
#  |-- SlogP_VSA9.1: double (nullable = true)
#  |-- SlogP_VSA10.1: double (nullable = true)
#  |-- SlogP_VSA11.1: double (nullable = true)
#  |-- SlogP_VSA12.1: double (nullable = true)
#  |-- fracVSA_PEOE01: double (nullable = true)
#  |-- fracVSA_PEOE02: double (nullable = true)
#  |-- fracVSA_PEOE03: double (nullable = true)
#  |-- fracVSA_PEOE04: double (nullable = true)
#  |-- fracVSA_PEOE05: double (nullable = true)
#  |-- fracVSA_PEOE06: double (nullable = true)
#  |-- fracVSA_PEOE07: double (nullable = true)
#  |-- fracVSA_PEOE08: double (nullable = true)
#  |-- fracVSA_PEOE09: double (nullable = true)
#  |-- fracVSA_PEOE10: double (nullable = true)
#  |-- fracVSA_PEOE11: double (nullable = true)
#  |-- fracVSA_PEOE12: double (nullable = true)
#  |-- fracVSA_PEOE13: double (nullable = true)
#  |-- fracVSA_PEOE14: double (nullable = true)
#  |-- fracVSA_SMR01: double (nullable = true)
#  |-- fracVSA_SMR02: double (nullable = true)
#  |-- fracVSA_SMR03: double (nullable = true)
#  |-- fracVSA_SMR04: double (nullable = true)
#  |-- fracVSA_SMR05: double (nullable = true)
#  |-- fracVSA_SMR06: double (nullable = true)
#  |-- fracVSA_SMR07: double (nullable = true)
#  |-- fracVSA_SMR08: double (nullable = true)
#  |-- fracVSA_SMR09: double (nullable = true)
#  |-- fracVSA_SMR10: double (nullable = true)
#  |-- fracVSA_SlogP01: double (nullable = true)
#  |-- fracVSA_SlogP02: double (nullable = true)
#  |-- fracVSA_SlogP03: double (nullable = true)
#  |-- fracVSA_SlogP04: double (nullable = true)
#  |-- fracVSA_SlogP05: double (nullable = true)
#  |-- fracVSA_SlogP06: double (nullable = true)
#  |-- fracVSA_SlogP07: double (nullable = true)
#  |-- fracVSA_SlogP08: double (nullable = true)
#  |-- fracVSA_SlogP09: double (nullable = true)
#  |-- fracVSA_SlogP10: double (nullable = true)
#  |-- fracVSA_SlogP11: double (nullable = true)
#  |-- fracVSA_SlogP12: double (nullable = true)
#  |-- label1: string (nullable = true)
#  |-- label2: string (nullable = true)
#  |-- label3a: string (nullable = true)
#  |-- label3b: string (nullable = true)
#  |-- drug_name: string (nullable = true)
#  |-- drug_smiles: string (nullable = true)
#  |-- ba_pct: double (nullable = true)
#  |-- frags_all: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_better: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_best: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_efgs: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- frags_brics: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %% [raw]
# test_subset = data_wLabels.select(['Name','BA_pct','MolWt','MolLogP','TPSA',
#                                    'label_QD5','label1','label2','label3a','label3b',
#                                        'label_cat0_vector','label_cat1_vector','label_cat2_vector','label_cat3_vector','label_cat4_vector',
#
# 'frags_all','frags_better','frags_best','frags_efgs','frags_brics',
#
# 'frags3_all','fragments3_subset','fragments3_subset2',
# 'frags4_all','frags4_subset','frags4_subset2'
# ])

# %%
data = data_final

# %%
''' 
# INTIAL LABELS:
# --- Data has 1 continuous label column, and 4 categorical label columns (discretized variants of continuous label).
# ------ categorical labels applied by dividing the continuous label values into 3-5 categories 
# ------ the value range associated with each group were selected based on histogram dist./mean/stdev
# --- We'll add one more discretization variant,  using Spark's built-in QuantileDiscretizer
'''
# -- Add QuantileDiscretizer labels
from pyspark.ml.feature import QuantileDiscretizer
import pandas as pd
qd5 = QuantileDiscretizer(numBuckets=5,inputCol='BA_pct',outputCol='label_QD5')

data_wLabels = qd5.fit(data).transform(data)

# -- INDEX / ENCODE LABELS
from pyspark.ml.feature import (StringIndexer,OneHotEncoder)

label_quant0 = 'BA_pct'
label_cat0_vector = OneHotEncoder(inputCol='label_QD5',outputCol='label_cat0_vector')

label_cat1_index = StringIndexer(inputCol='label1',outputCol='label_cat1_index')
label_cat1_vector = OneHotEncoder(inputCol='label_cat1_index',outputCol='label_cat1_vector')

label_cat2_index = StringIndexer(inputCol='label2',outputCol='label_cat2_index')
label_cat2_vector = OneHotEncoder(inputCol='label_cat2_index',outputCol='label_cat2_vector')

label_cat3_index = StringIndexer(inputCol='label3a',outputCol='label_cat3_index')
label_cat3_vector = OneHotEncoder(inputCol='label_cat3_index',outputCol='label_cat3_vector')

label_cat4_index = StringIndexer(inputCol='label3b',outputCol='label_cat4_index')
label_cat4_vector = OneHotEncoder(inputCol='label_cat4_index',outputCol='label_cat4_vector')

from pyspark.ml import Pipeline
label_pipeline = Pipeline(stages=[label_cat0_vector,
                                 label_cat1_index,label_cat1_vector,
                                 label_cat2_index,label_cat2_vector,
                                 label_cat3_index,label_cat3_vector,
                                 label_cat4_index,label_cat4_vector])
data_wLabels = label_pipeline.fit(data_wLabels).transform(data_wLabels)

# %% [markdown]
# ## Test predictions by fragment data alone

# %% [raw]
# test_subset = data_wLabels.select(['Name','BA_pct','MolWt','MolLogP','TPSA',
#                                    'label_QD5','label1','label2','label3a','label3b',
#                                    'label_cat0_vector','label_cat1_vector','label_cat2_vector','label_cat3_vector','label_cat4_vector',
#                                   'frags_all','frags_better','frags_best','frags_efgs','frags_brics'])

# %%
test_subset = data_wLabels.select(['Name','BA_pct','label1','label2','label3a','label3b',
                                   'label_cat1_index','label_cat2_index','label_cat3_index','label_cat4_index','label_QD5',
                                   'frags_all','frags_better','frags_best','frags_efgs','frags_brics',
                                   'frags3_all','fragments3_subset','fragments3_subset2',
                                   'frags4_all','fragments4_subset','fragments4_subset2'])

# %%
from pyspark.ml.feature import NGram,Word2Vec,CountVectorizer,HashingTF,IDF

# %% [raw]
# ''' # Fragments NLP processing  - NEW -
# '''
#
# from pyspark.ml.feature import NGram,Word2Vec,CountVectorizer,HashingTF,IDF
#
# fragment_types = ['frags_all','frags_better','frags_best','frags_efgs','frags_brics']
# test_subset_nlp = test_subset
# for frag_type in fragment_types:
#
#
#     #output_name_level1 = f"nlp_{frag_type}"
#     frag_type_short = frag_type.replace('frags_','')
#
#     cv = CountVectorizer(inputCol=frag_type, outputCol=f"{frag_type_short}_cv", minDF=2.0)
#     cv_idf = IDF(inputCol=f"{frag_type_short}_cv", outputCol=f"{frag_type_short}_cv_idf")
#
#     w2v = Word2Vec(inputCol=frag_type, outputCol=f"{frag_type_short}_w2v")
#
#     n2gram = NGram(n=2, inputCol=frag_type, outputCol=f"{frag_type_short}_n2g")
#     n2gram_cv = CountVectorizer(inputCol=f"{frag_type_short}_n2g", outputCol=f"{frag_type_short}_n2g_cv", minDF=2.0)
#     n2gram_cv_idf = IDF(inputCol=f"{frag_type_short}_n2g_cv", outputCol=f"{frag_type_short}_n2g_cv_idf")
#
#
#     nlp_pipeline = Pipeline(stages=[cv,cv_idf,w2v,n2gram,n2gram_cv,n2gram_cv_idf])
#     test_subset_nlp = nlp_pipeline.fit(test_subset_nlp).transform(test_subset_nlp)

# %%
        
''' # Fragments NLP processing  - NEWER -
'''

from pyspark.ml.feature import NGram,Word2Vec,CountVectorizer,HashingTF,IDF

fragment_types = ['frags_all','frags_better','frags_best', #'frags_efgs','frags_brics',
                                   'frags3_all','fragments3_subset','fragments3_subset2',
                                   'frags4_all','fragments4_subset','fragments4_subset2']
fragment_shortname = ['f1_all','f1_subset','f1_subset2', #'frags_efgs','frags_brics',
                                   'f3_all','f3_subset','f3_subset2',
                                   'f4_all','f4_subset','f4_subset2']

test_subset_nlp = test_subset
for i,frag_type in enumerate(fragment_types):
    
    
    #output_name_level1 = f"nlp_{frag_type}"
    frag_type_short = fragment_shortname[i]
    
    cv = CountVectorizer(inputCol=frag_type, outputCol=f"{frag_type_short}_cv", minDF=2.0)
    
    w2v = Word2Vec(inputCol=frag_type, outputCol=f"{frag_type_short}_w2v")
    
    n2gram = NGram(n=2, inputCol=frag_type, outputCol=f"{frag_type_short}_n2g")
    n2gram_cv = CountVectorizer(inputCol=f"{frag_type_short}_n2g", outputCol=f"{frag_type_short}_n2g_cv", minDF=2.0)
    
    
    nlp_pipeline = Pipeline(stages=[cv,w2v,n2gram,n2gram_cv])
    test_subset_nlp = nlp_pipeline.fit(test_subset_nlp).transform(test_subset_nlp)
    
    #column_to_drop = f"{frag_type_short}_n2g"
    #test_subset_nlp = test_subset_nlp.drop(column_to_drop)

# %% [raw]
# test_subset_nlp = test_subset_nlp.select(['Name','BA_pct','MolWt','MolLogP','TPSA',#'label_QD5','label1','label2','label3a','label3b','label_cat0_vector','label_cat1_vector','label_cat2_vector','label_cat3_vector','label_cat4_vector',
#                                       'all_cv', 'all_cv_idf', 'all_w2v', 'all_n2g_cv', 'all_n2g_cv_idf',
#                                       'better_cv', 'better_cv_idf', 'better_w2v', 'better_n2g_cv', 'better_n2g_cv_idf',
#                                       'best_cv', 'best_cv_idf', 'best_w2v', 'best_n2g_cv', 'best_n2g_cv_idf',
#                                       'efgs_cv', 'efgs_cv_idf', 'efgs_w2v', 'efgs_n2g_cv', 'efgs_n2g_cv_idf',
#                                       'brics_cv', 'brics_cv_idf', 'brics_w2v', 'brics_n2g_cv', 'brics_n2g_cv_idf'])
#
# from pyspark.ml.linalg import Vector
# from pyspark.ml.feature import (VectorAssembler,VectorIndexer)
#
# vector_assemblers = []
#
# alternative_features = ['all_cv', 'all_cv_idf', 'all_w2v', 'all_n2g_cv', 'all_n2g_cv_idf',
#                       'better_cv', 'better_cv_idf', 'better_w2v', 'better_n2g_cv', 'better_n2g_cv_idf',
#                       'best_cv', 'best_cv_idf', 'best_w2v', 'best_n2g_cv', 'best_n2g_cv_idf',
#                       'efgs_cv', 'efgs_cv_idf', 'efgs_w2v', 'efgs_n2g_cv', 'efgs_n2g_cv_idf',
#                       'brics_cv', 'brics_cv_idf', 'brics_w2v', 'brics_n2g_cv', 'brics_n2g_cv_idf']
# output_features = ""
# for feats in alternative_features:
#     #feats_input = ['MolWt','MolLogP','TPSA',feats]
#     feats_input = [feats]
#     feats_output = f"FEAT_{feats}"
#
#     vec_assembler = VectorAssembler(inputCols=feats_input, outputCol=feats_output)
#
#     vector_assemblers.append(vec_assembler)
#
#     output_features += "'"+feats_output+"'"+", "
# output_features = output_features[0:len(output_features)-2]
# print(output_features)
#
# from pyspark.ml import Pipeline
# feature_pipeline = Pipeline(stages=[x for x in vector_assemblers])
#
# test_subset_nlpFeatures = feature_pipeline.fit(test_subset_nlp).transform(test_subset_nlp)

# %%
test_subset_nlp = test_subset_nlp.select(['Name','BA_pct',
                                          'label_cat1_index','label_cat2_index','label_cat3_index','label_cat4_index','label_QD5',
                                          'f1_all_cv','f1_all_w2v','f1_all_n2g_cv',
                                          'f1_subset_cv','f1_subset_w2v','f1_subset_n2g_cv',
                                          'f1_subset2_cv','f1_subset2_w2v','f1_subset2_n2g_cv',
                                          'f3_all_cv','f3_all_w2v','f3_all_n2g_cv',
                                          'f3_subset_cv','f3_subset_w2v','f3_subset_n2g_cv',
                                          'f3_subset2_cv','f3_subset2_w2v','f3_subset2_n2g_cv',
                                          'f4_all_cv','f4_all_w2v','f4_all_n2g_cv',
                                          'f4_subset_cv','f4_subset_w2v','f4_subset_n2g_cv',
                                          'f4_subset2_cv','f4_subset2_w2v','f4_subset2_n2g_cv'])

from pyspark.ml.linalg import Vector
from pyspark.ml.feature import (VectorAssembler,VectorIndexer)

vector_assemblers = []

alternative_features = ['f1_all_cv','f1_all_w2v','f1_all_n2g_cv',
                        'f1_subset_cv','f1_subset_w2v','f1_subset_n2g_cv',
                        'f1_subset2_cv','f1_subset2_w2v','f1_subset2_n2g_cv',
                        'f3_all_cv','f3_all_w2v','f3_all_n2g_cv',
                        'f3_subset_cv','f3_subset_w2v','f3_subset_n2g_cv',
                        'f3_subset2_cv','f3_subset2_w2v','f3_subset2_n2g_cv',
                        'f4_all_cv','f4_all_w2v','f4_all_n2g_cv',
                        'f4_subset_cv','f4_subset_w2v','f4_subset_n2g_cv',
                        'f4_subset2_cv','f4_subset2_w2v','f4_subset2_n2g_cv']
output_features = ""
for feats in alternative_features:
    #feats_input = ['MolWt','MolLogP','TPSA',feats]
    feats_input = [feats]
    feats_output = f"FEAT_{feats}"
    
    vec_assembler = VectorAssembler(inputCols=feats_input, outputCol=feats_output)
    
    vector_assemblers.append(vec_assembler)
    
    output_features += "'"+feats_output+"'"+", "
output_features = output_features[0:len(output_features)-2]
print(output_features)

from pyspark.ml import Pipeline
feature_pipeline = Pipeline(stages=[x for x in vector_assemblers])

test_subset_nlpFeatures = feature_pipeline.fit(test_subset_nlp).transform(test_subset_nlp)
# Out:
# 'FEAT_f1_all_cv', 'FEAT_f1_all_w2v', 'FEAT_f1_all_n2g_cv', 'FEAT_f1_subset_cv', 'FEAT_f1_subset_w2v', 'FEAT_f1_subset_n2g_cv', 'FEAT_f1_subset2_cv', 'FEAT_f1_subset2_w2v', 'FEAT_f1_subset2_n2g_cv', 'FEAT_f3_all_cv', 'FEAT_f3_all_w2v', 'FEAT_f3_all_n2g_cv', 'FEAT_f3_subset_cv', 'FEAT_f3_subset_w2v', 'FEAT_f3_subset_n2g_cv', 'FEAT_f3_subset2_cv', 'FEAT_f3_subset2_w2v', 'FEAT_f3_subset2_n2g_cv', 'FEAT_f4_all_cv', 'FEAT_f4_all_w2v', 'FEAT_f4_all_n2g_cv', 'FEAT_f4_subset_cv', 'FEAT_f4_subset_w2v', 'FEAT_f4_subset_n2g_cv', 'FEAT_f4_subset2_cv', 'FEAT_f4_subset2_w2v', 'FEAT_f4_subset2_n2g_cv'

# %% [raw]
# test_subset_final = test_subset_nlpFeatures.select(['Name','BA_pct',
#                         'all_cv', 'all_cv_idf', 'all_w2v', 'all_n2g_cv', 'all_n2g_cv_idf',
#                       'better_cv', 'better_cv_idf', 'better_w2v', 'better_n2g_cv', 'better_n2g_cv_idf',
#                       'best_cv', 'best_cv_idf', 'best_w2v', 'best_n2g_cv', 'best_n2g_cv_idf',
#                       'efgs_cv', 'efgs_cv_idf', 'efgs_w2v', 'efgs_n2g_cv', 'efgs_n2g_cv_idf',
#                       'brics_cv', 'brics_cv_idf', 'brics_w2v', 'brics_n2g_cv', 'brics_n2g_cv_idf'])
#
# (training,testing) = test_subset_final.randomSplit([0.7,0.3])

# %% [raw]
# allFeatures =  ['all_cv', 'all_cv_idf', 'all_w2v', 'all_n2g_cv', 'all_n2g_cv_idf',
#                       'better_cv', 'better_cv_idf', 'better_w2v', 'better_n2g_cv', 'better_n2g_cv_idf',
#                       'best_cv', 'best_cv_idf', 'best_w2v', 'best_n2g_cv', 'best_n2g_cv_idf',
#                       'efgs_cv', 'efgs_cv_idf', 'efgs_w2v', 'efgs_n2g_cv', 'efgs_n2g_cv_idf',
#                       'brics_cv', 'brics_cv_idf', 'brics_w2v', 'brics_n2g_cv', 'brics_n2g_cv_idf']
# featuresName = '' # temp value, redefined below
#
# eval_df = pd.DataFrame() # already exists from prior run
# labelName = 'BA_pct'  # SPECIFY
#
# modelname_short = 'rfr'
# iteration = 4
#
# '''
# # Load Evaluation History records file
# '''
# with open('evaluation_history.pickle', 'rb') as handle:
#     evaluation_history = pickle.load(handle)
#
# evaluation_history[modelname_short] = {}
# evaluation_history[modelname_short][iteration] = {}
# evaluation_history[modelname_short][iteration]['source'] = 'frags_all'
# evaluation_history[modelname_short][iteration]['label'] = labelName
#
#
# for index,features in enumerate(allFeatures):
#     featuresName = features
#
#     '''# SPECIFY MODEL
#     '''
#     from pyspark.ml.regression import RandomForestRegressor
#     rfr = RandomForestRegressor(featuresCol=features,labelCol='BA_pct')
#     modeltype = rfr  # SPECIFY (lr,dtr,rfr,gbtr,glr,ir)
#
#
#     modelname = f"rfr{iteration}_{allFeatures[index]}"
#     modelname = modelname.replace('features_','')
#
#     evaluation_history[modelname_short][iteration][features] = {}
#
#     # FIT/TRAIN MODEL & TRANSFORM DATA
#     mymodel = modeltype.fit(training)
#     myresults = mymodel.transform(testing)
#
#     # CALCULATE KEY EVALS
#     from pyspark.ml.evaluation import RegressionEvaluator
#     regEvaluator = RegressionEvaluator(labelCol=labelName,predictionCol='prediction')
#
#     evaluator = regEvaluator
#     evalMetrics = {regEvaluator:['rmse','mse','mae','r2','var']}
#
#     evaluation = []
#
#     for each_metric in evalMetrics[evaluator]:
#         metric = each_metric
#
#         result = evaluator.evaluate(myresults, {evaluator.metricName: metric})
#
#         evaluation.append((metric,result))
#
#         evaluation_history[modelname_short][iteration][features][metric] = result
#
#     #r2_adj = mymodel.summary.r2adj
#     #evaluation.append(('r2_adj(Training)',r2_adj))
#     column0 = [x for x,y in evaluation]
#     column1 = [y for x,y in evaluation]
#     eval_df['metric'] = column0
#     eval_df[modelname] = column1
#
# ''' # BACKUP EVALUATION HISTORY
# '''
# import pickle
# with open('evaluation_history.pickle', 'wb') as handle:
#     pickle.dump(evaluation_history, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [raw]
# # iteration 4
# pd.set_option('display.max_columns',None)
# eval_df

# %%
test_subset_final = test_subset_nlpFeatures.select(['Name','BA_pct',
                                                    'FEAT_f1_all_cv', 'FEAT_f1_all_w2v', 'FEAT_f1_all_n2g_cv', 
                                                    'FEAT_f1_subset_cv', 'FEAT_f1_subset_w2v', 'FEAT_f1_subset_n2g_cv', 'FEAT_f1_subset2_cv', 'FEAT_f1_subset2_w2v', 'FEAT_f1_subset2_n2g_cv', 'FEAT_f3_all_cv', 'FEAT_f3_all_w2v', 'FEAT_f3_all_n2g_cv', 'FEAT_f3_subset_cv', 'FEAT_f3_subset_w2v', 'FEAT_f3_subset_n2g_cv', 'FEAT_f3_subset2_cv', 'FEAT_f3_subset2_w2v', 'FEAT_f3_subset2_n2g_cv', 'FEAT_f4_all_cv', 'FEAT_f4_all_w2v', 'FEAT_f4_all_n2g_cv', 'FEAT_f4_subset_cv', 'FEAT_f4_subset_w2v', 'FEAT_f4_subset_n2g_cv',
                                                    'FEAT_f4_subset2_cv', 'FEAT_f4_subset2_w2v', 'FEAT_f4_subset2_n2g_cv'])

(training,testing) = test_subset_final.randomSplit([0.7,0.3])

# %%
allFeatures =  ['FEAT_f1_all_cv', 'FEAT_f1_all_w2v', 'FEAT_f1_all_n2g_cv', 
                'FEAT_f1_subset_cv', 'FEAT_f1_subset_w2v', 'FEAT_f1_subset_n2g_cv', 'FEAT_f1_subset2_cv', 'FEAT_f1_subset2_w2v', 'FEAT_f1_subset2_n2g_cv', 'FEAT_f3_all_cv', 'FEAT_f3_all_w2v', 'FEAT_f3_all_n2g_cv', 'FEAT_f3_subset_cv', 'FEAT_f3_subset_w2v', 'FEAT_f3_subset_n2g_cv', 'FEAT_f3_subset2_cv', 'FEAT_f3_subset2_w2v', 'FEAT_f3_subset2_n2g_cv', 'FEAT_f4_all_cv', 'FEAT_f4_all_w2v', 'FEAT_f4_all_n2g_cv', 'FEAT_f4_subset_cv', 'FEAT_f4_subset_w2v', 'FEAT_f4_subset_n2g_cv',
                'FEAT_f4_subset2_cv', 'FEAT_f4_subset2_w2v', 'FEAT_f4_subset2_n2g_cv']
featuresName = '' # temp value, redefined below

eval_df = pd.DataFrame() # already exists from prior run
labelName = 'BA_pct'  # SPECIFY

modelname_short = 'rfr'
iteration = 0


for index,features in enumerate(allFeatures):
    featuresName = features
    
    '''# SPECIFY MODEL 
    '''
    from pyspark.ml.regression import RandomForestRegressor
    rfr = RandomForestRegressor(featuresCol=features,labelCol='BA_pct')
    modeltype = rfr  # SPECIFY (lr,dtr,rfr,gbtr,glr,ir)
    
    
    modelname = f"rfr{iteration}_{allFeatures[index]}"
    modelname = modelname.replace('features_','')
    
    #evaluation_history[modelname_short][iteration][features] = {}
    
    # FIT/TRAIN MODEL & TRANSFORM DATA
    mymodel = modeltype.fit(training)
    myresults = mymodel.transform(testing)
    
    # CALCULATE KEY EVALS
    from pyspark.ml.evaluation import RegressionEvaluator
    regEvaluator = RegressionEvaluator(labelCol=labelName,predictionCol='prediction')

    evaluator = regEvaluator
    evalMetrics = {regEvaluator:['rmse','mse','mae','r2','var']}
    
    evaluation = []
    
    for each_metric in evalMetrics[evaluator]:        
        metric = each_metric

        result = evaluator.evaluate(myresults, {evaluator.metricName: metric})

        evaluation.append((metric,result))
        
        #evaluation_history[modelname_short][iteration][features][metric] = result
        
    #r2_adj = mymodel.summary.r2adj
    #evaluation.append(('r2_adj(Training)',r2_adj))
    column0 = [x for x,y in evaluation]
    column1 = [y for x,y in evaluation]
    eval_df['metric'] = column0
    eval_df[modelname] = column1
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.util.SizeEstimator$ (file:/home/mitch/spark-3.3.0-bin-hadoop2/jars/spark-core_2.12-3.3.0.jar) to field java.nio.charset.Charset.name
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.util.SizeEstimator$
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release

# %%
# iteration 4
pd.set_option('display.max_columns',None)
eval_df
# Out:
#   metric  rfr0_FEAT_f1_all_cv  rfr0_FEAT_f1_all_w2v  rfr0_FEAT_f1_all_n2g_cv  \
# 0   rmse            30.545633             31.789093                31.482326
# 1    mse           933.035718           1010.546432               991.136821
# 2    mae            26.473072             27.448813                27.156987
# 3     r2             0.146418              0.075508                 0.093265
# 4    var            88.923536             77.944790                77.799296
#
#    rfr0_FEAT_f1_subset_cv  rfr0_FEAT_f1_subset_w2v  \
# 0               30.564196                31.726298
# 1              934.170067              1006.557991
# 2               26.627258                27.306151
# 3                0.145380                 0.079157
# 4               92.138939                92.857502
#
#    rfr0_FEAT_f1_subset_n2g_cv  rfr0_FEAT_f1_subset2_cv  \
# 0                   31.020037                33.069712
# 1                  962.242718              1093.605851
# 2                   26.971851                28.916071
# 3                    0.119698                -0.000478
# 4                   79.162455                 0.522849
#
#    rfr0_FEAT_f1_subset2_w2v  rfr0_FEAT_f1_subset2_n2g_cv  rfr0_FEAT_f3_all_cv  \
# 0                 33.069712                    33.069712            30.534229
# 1               1093.605851                  1093.605851           932.339167
# 2                 28.916071                    28.916071            26.523584
# 3                 -0.000478                    -0.000478             0.147055
# 4                  0.522849                     0.522849            86.305266
#
#    rfr0_FEAT_f3_all_w2v  rfr0_FEAT_f3_all_n2g_cv  rfr0_FEAT_f3_subset_cv  \
# 0             31.345774                30.773345               30.447927
# 1            982.557563               946.998741              927.076241
# 2             26.985489                26.810127               26.546661
# 3              0.101113                 0.133644                0.151870
# 4             91.045544                64.251850               97.333164
#
#    rfr0_FEAT_f3_subset_w2v  rfr0_FEAT_f3_subset_n2g_cv  \
# 0                31.751381                   30.947886
# 1              1008.150201                  957.771639
# 2                27.501475                   27.028072
# 3                 0.077700                    0.123789
# 4                88.922355                   68.100017
#
#    rfr0_FEAT_f3_subset2_cv  rfr0_FEAT_f3_subset2_w2v  \
# 0                30.503084                 31.849818
# 1               930.438121               1014.410931
# 2                26.504800                 27.556700
# 3                 0.148795                  0.071973
# 4                84.366305                104.947788
#
#    rfr0_FEAT_f3_subset2_n2g_cv  rfr0_FEAT_f4_all_cv  rfr0_FEAT_f4_all_w2v  \
# 0                    31.264448            30.415623             30.797625
# 1                   977.465708           925.110133            948.493725
# 2                    27.366346            26.353785             26.684042
# 3                     0.105772             0.153669              0.132277
# 4                    52.384987           106.228991             73.144633
#
#    rfr0_FEAT_f4_all_n2g_cv  rfr0_FEAT_f4_subset_cv  rfr0_FEAT_f4_subset_w2v  \
# 0                30.430185               30.338131                31.159594
# 1               925.996143              920.402163               970.920277
# 2                26.325146               26.412459                26.950824
# 3                 0.152858                0.157976                 0.111760
# 4               112.358499              105.179987                85.201956
#
#    rfr0_FEAT_f4_subset_n2g_cv  rfr0_FEAT_f4_subset2_cv  \
# 0                   30.457680                30.407232
# 1                  927.670282               924.599779
# 2                   26.499474                26.412425
# 3                    0.151327                 0.154136
# 4                  114.784128               112.576371
#
#    rfr0_FEAT_f4_subset2_w2v  rfr0_FEAT_f4_subset2_n2g_cv
# 0                 30.884744                    30.416505
# 1                953.867439                   925.163779
# 2                 26.541026                    26.394901
# 3                  0.127360                     0.153620
# 4                 79.931642                   108.829463

# %%
# best features in terms of r2: 
testx = eval_df.set_index('metric')
testx = testx.transpose()
testx.sort_values(by=['r2'],ascending=False)
# Out:
# metric                            rmse          mse        mae        r2  \
# rfr0_FEAT_f4_subset_cv       30.338131   920.402163  26.412459  0.157976
# rfr0_FEAT_f4_subset2_cv      30.407232   924.599779  26.412425  0.154136
# rfr0_FEAT_f4_all_cv          30.415623   925.110133  26.353785  0.153669
# rfr0_FEAT_f4_subset2_n2g_cv  30.416505   925.163779  26.394901  0.153620
# rfr0_FEAT_f4_all_n2g_cv      30.430185   925.996143  26.325146  0.152858
# rfr0_FEAT_f3_subset_cv       30.447927   927.076241  26.546661  0.151870
# rfr0_FEAT_f4_subset_n2g_cv   30.457680   927.670282  26.499474  0.151327
# rfr0_FEAT_f3_subset2_cv      30.503084   930.438121  26.504800  0.148795
# rfr0_FEAT_f3_all_cv          30.534229   932.339167  26.523584  0.147055
# rfr0_FEAT_f1_all_cv          30.545633   933.035718  26.473072  0.146418
# rfr0_FEAT_f1_subset_cv       30.564196   934.170067  26.627258  0.145380
# rfr0_FEAT_f3_all_n2g_cv      30.773345   946.998741  26.810127  0.133644
# rfr0_FEAT_f4_all_w2v         30.797625   948.493725  26.684042  0.132277
# rfr0_FEAT_f4_subset2_w2v     30.884744   953.867439  26.541026  0.127360
# rfr0_FEAT_f3_subset_n2g_cv   30.947886   957.771639  27.028072  0.123789
# rfr0_FEAT_f1_subset_n2g_cv   31.020037   962.242718  26.971851  0.119698
# rfr0_FEAT_f4_subset_w2v      31.159594   970.920277  26.950824  0.111760
# rfr0_FEAT_f3_subset2_n2g_cv  31.264448   977.465708  27.366346  0.105772
# rfr0_FEAT_f3_all_w2v         31.345774   982.557563  26.985489  0.101113
# rfr0_FEAT_f1_all_n2g_cv      31.482326   991.136821  27.156987  0.093265
# rfr0_FEAT_f1_subset_w2v      31.726298  1006.557991  27.306151  0.079157
# rfr0_FEAT_f3_subset_w2v      31.751381  1008.150201  27.501475  0.077700
# rfr0_FEAT_f1_all_w2v         31.789093  1010.546432  27.448813  0.075508
# rfr0_FEAT_f3_subset2_w2v     31.849818  1014.410931  27.556700  0.071973
# rfr0_FEAT_f1_subset2_w2v     33.069712  1093.605851  28.916071 -0.000478
# rfr0_FEAT_f1_subset2_n2g_cv  33.069712  1093.605851  28.916071 -0.000478
# rfr0_FEAT_f1_subset2_cv      33.069712  1093.605851  28.916071 -0.000478
#
# metric                              var
# rfr0_FEAT_f4_subset_cv       105.179987
# rfr0_FEAT_f4_subset2_cv      112.576371
# rfr0_FEAT_f4_all_cv          106.228991
# rfr0_FEAT_f4_subset2_n2g_cv  108.829463
# rfr0_FEAT_f4_all_n2g_cv      112.358499
# rfr0_FEAT_f3_subset_cv        97.333164
# rfr0_FEAT_f4_subset_n2g_cv   114.784128
# rfr0_FEAT_f3_subset2_cv       84.366305
# rfr0_FEAT_f3_all_cv           86.305266
# rfr0_FEAT_f1_all_cv           88.923536
# rfr0_FEAT_f1_subset_cv        92.138939
# rfr0_FEAT_f3_all_n2g_cv       64.251850
# rfr0_FEAT_f4_all_w2v          73.144633
# rfr0_FEAT_f4_subset2_w2v      79.931642
# rfr0_FEAT_f3_subset_n2g_cv    68.100017
# rfr0_FEAT_f1_subset_n2g_cv    79.162455
# rfr0_FEAT_f4_subset_w2v       85.201956
# rfr0_FEAT_f3_subset2_n2g_cv   52.384987
# rfr0_FEAT_f3_all_w2v          91.045544
# rfr0_FEAT_f1_all_n2g_cv       77.799296
# rfr0_FEAT_f1_subset_w2v       92.857502
# rfr0_FEAT_f3_subset_w2v       88.922355
# rfr0_FEAT_f1_all_w2v          77.944790
# rfr0_FEAT_f3_subset2_w2v     104.947788
# rfr0_FEAT_f1_subset2_w2v       0.522849
# rfr0_FEAT_f1_subset2_n2g_cv    0.522849
# rfr0_FEAT_f1_subset2_cv        0.522849

# %% [markdown]
# ### Results:
# **Findings:**
# 1. the most effective fragment representation is `frags_all`
# 2. the most effective nlp representation is **CountVectorizer** or CV-IDF > bigram CV > word2vec
